# %%
# Print the welcome message for the user
print("\n'Welcome to the PyLogic Suite: Integrated Pyramid Generator & Number Analyzer'".upper())

# Start a loop to keep the program running until the user chooses to exit
while True:
    # Display the menu options
    print("\nChoose Your Number: ")
    print("\n1. Pattern Generator")
    print("2. Number Analyzer")
    print("3. Know You Birth Year")
    print("4. Exit")
    
    # Get the user's choice
    user = int(input("\nEnter Your Number"))
    
    # Option 1: Pattern Generator logic
    if user == 1:
        print("\nWelcome to Pattern Generator:".upper())

        Number = int(input("Enter Row For Pyramid: "))

        # Loop to print the pyramid pattern based on the number of rows
        for i in range(1, Number + 1):
            print(" " * (Number - i) + "*" * (2 * i - 1))
              
    # Option 2: Number Analyzer logic
    elif user == 2:
        print("\nWelcome to the Number Analyzer".upper())

        Number_1 = int(input("Enter Your Number 1: "))
        Number_2 = int(input("Enter Your Number 2: "))
        print(f"\nODD and EVEN Numbers between {Number_1} and {Number_2}".upper())
        print("\n")
        
        # Loop through the range to check if numbers are Odd or Even
        for i in range(Number_1, Number_2 + 1):
            if i % 2 == 0:
                print(f"{i}: EVEN Number")
            else:
                print(f"{i}: ODD Number")
    
    # Option 3: Birth Year calculator logic
    elif user == 3:
        print("\nKnow Your Birth Year By Your Age".upper())

        age = int(input("Enter Your Age"))

        # Calculate birth year based on current year 2026
        Birth_Year = 2026 - age

        print(f"\n'Your Birth Year Is {Birth_Year}, Based On Your Age!'")

    # Option 4: Exit the program
    elif user == 4:
        print("\nThank You! For Using This Program, Goodbye!")
        break

    # Handle invalid menu selections
    elif user > 4:
        print(f"Sorry, Your Number {user} Is Not In Option.")
# Out:
# 'WELCOME TO THE PYLOGIC SUITE: INTEGRATED PYRAMID GENERATOR & NUMBER ANALYZER'
#
# Choose Your Number:
#
# 1. Pattern Generator
# 2. Number Analyzer
# 3. Know You Birth Year
# 4. Exit
# Enter Your Number 1
# WELCOME TO PATTERN GENERATOR:
# Enter Row For Pyramid:  5
#     *
#    ***
#   *****
#  *******
# *********
#
# Choose Your Number:
#
# 1. Pattern Generator
# 2. Number Analyzer
# 3. Know You Birth Year
# 4. Exit
# Enter Your Number 2
# WELCOME TO THE NUMBER ANALYZER
# Enter Your Number 1:  21
# Enter Your Number 2:  30
# ODD AND EVEN NUMBERS BETWEEN 21 AND 30
#
#
# 21: ODD Number
# 22: EVEN Number
# 23: ODD Number
# 24: EVEN Number
# 25: ODD Number
# 26: EVEN Number
# 27: ODD Number
# 28: EVEN Number
# 29: ODD Number
# 30: EVEN Number
#
# Choose Your Number:
#
# 1. Pattern Generator
# 2. Number Analyzer
# 3. Know You Birth Year
# 4. Exit
# Enter Your Number 3
# KNOW YOUR BIRTH YEAR BY YOUR AGE
# Enter Your Age 20
# 'Your Birth Year Is 2006, Based On Your Age!'
#
# Choose Your Number:
#
# 1. Pattern Generator
# 2. Number Analyzer
# 3. Know You Birth Year
# 4. Exit
# Enter Your Number 4
# Thank You! For Using This Program, Goodbye!
